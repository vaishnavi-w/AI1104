# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# Number of training samples
N = 10
# Generate equi spaced floats in the interval [0, 2*pi]
x = np.linspace(0, 2*np.pi, N)
# Generate noice
mean = 0 
std = 0.05
# Generate some numbers from the sine function 
y = np.sin(x)
# Add noise
y += np.random.normal(mean,std,N)

# Generate an array of ones of size (N, 2)
X = np.ones([N,2])
# Replacing ones in the matrix in the second column with x
X[:,1] = np.array(x).T

# Calculating vector beta = = (X^T.X)^(-1).X^T.y of model parameters
# X transpose 
X_transpose = X.T
# Matrix multiplication of X transpose and X
Z = np.dot(X_transpose, X)
# Calculating of pseudo inverse matrix
Pseudo_inverse = np.linalg.inv(Z)
# Multiplying pseudo inverse, X transpose and Y matrices 
B = Pseudo_inverse @ X_transpose @ y 

print('Model parameters : ', B)

# Predicted labels
y_hat = np.dot(X, B)

# TESTING SAMPLES
# Number of testing samples
T = 5
# Generate equi spaced floats in the interval [0, 2*pi]
test_x = np.linspace(0, 2*np.pi, T)
# Generate noice
mean = 0 
std = 0.05
# Generate some numbers from the sine function 
test_y = np.sin(test_x)
# Add noise
test_y += np.random.normal(mean,std,T)

# Initializing null vector for predicted labels
test_y_hat = np.zeros(T)
# Calculating predicted labels
for i in range(T):
    test_y_hat[i] = B[0] + B[1]*test_x[i]

# Mean square error for the testing sample
error = np.square(test_y - test_y_hat).mean()
error_train = np.square(y - y_hat).mean()
print('MSE between the predicted and ground truth labels in testing data:',error_train)
print('MSE between the predicted and ground truth labels for testing data :', error)

# Displaying the data
plt.plot(x,y,'go',label='Training data')
plt.plot(test_x,test_y_hat,'rx',label='Testing data')
plt.plot(x,y_hat)
plt.axis('equal')
plt.grid(True)
plt.legend(loc='best')
plt.show()
print('Observations : The ML model performs poorly on the test and the training data. It is underfitting, does not fit the data well enough.')

# %%
# Number of training samples
N = 100
# Generate equi spaced floats in the interval [0, 2*pi]
x = np.linspace(0, 2*np.pi, N)
# Generate noice
mean = 0 
std = 0.05
# Generate some numbers from the sine function 
y = np.sin(x)
# Add noise
y += np.random.normal(mean,std,N)

# Generate an array of ones of size (N, 2)
X = np.ones([N,2])
# Replacing ones in the matrix in the second column with x
X[:,1] = np.array(x).T

# Calculating vector beta = = (X^T.X)^(-1).X^T.y of model parameters
# X transpose 
X_transpose = X.T
# Matrix multiplication of X transpose and X
Z = np.dot(X_transpose, X)
# Calculating of pseudo inverse matrix
Pseudo_inverse = np.linalg.inv(Z)
# Multiplying pseudo inverse, X transpose and Y matrices 
B = Pseudo_inverse @ X_transpose @ y 

print('Model parameters : ', B)

# Predicted labels
y_hat = np.dot(X, B)

# TESTING SAMPLES
# Number of testing samples
T = 10
# Generate equi spaced floats in the interval [0, 2*pi]
test_x = np.linspace(0, 2*np.pi, T)
# Generate noice
mean = 0 
std = 0.05
# Generate some numbers from the sine function 
test_y = np.sin(test_x)
# Add noise
test_y += np.random.normal(mean,std,T)

# Initializing null vector for predicted labels
test_y_hat = np.zeros(T)
# Calculating predicted labels
for i in range(T):
    test_y_hat[i] = B[0] + B[1]*test_x[i]

# Mean square error for the testing sample
error = np.square(test_y - test_y_hat).mean()
error_train = np.square(y - y_hat).mean()
print('MSE between the predicted and ground truth labels in testing data:',error_train)
print('MSE between the predicted and ground truth labels for testing data :', error)

# Displaying the data
plt.plot(x,y,'go',label='Training data')
plt.plot(test_x,test_y_hat,'rx',label='Testing data')
plt.plot(x,y_hat)
plt.axis('equal')
plt.grid(True)
plt.legend(loc='best')
plt.show()
print('Observations : The ML model performs poorly on the test and the training data. It is underfitting, does not fit the data well enough.')

# %%
# Number of training samples
N = 1000
# Generate equi spaced floats in the interval [0, 2*pi]
x = np.linspace(0, 2*np.pi, N)
# Generate noice
mean = 0 
std = 0.05
# Generate some numbers from the sine function 
y = np.sin(x)
# Add noise
y += np.random.normal(mean,std,N)

# Generate an array of ones of size (N, 2)
X = np.ones([N,2])
# Replacing ones in the matrix in the second column with x
X[:,1] = np.array(x).T

# Calculating vector beta = = (X^T.X)^(-1).X^T.y of model parameters
# X transpose 
X_transpose = X.T
# Matrix multiplication of X transpose and X
Z = np.dot(X_transpose, X)
# Calculating of pseudo inverse matrix
Pseudo_inverse = np.linalg.inv(Z)
# Multiplying pseudo inverse, X transpose and Y matrices 
B = Pseudo_inverse @ X_transpose @ y 

print('Model parameters : ', B)

# Predicted labels
y_hat = np.dot(X, B)

# TESTING SAMPLES
# Number of testing samples
T = 20
# Generate equi spaced floats in the interval [0, 2*pi]
test_x = np.linspace(0, 2*np.pi, T)
# Generate noice
mean = 0 
std = 0.05
# Generate some numbers from the sine function 
test_y = np.sin(test_x)
# Add noise
test_y += np.random.normal(mean,std,T)

# Initializing null vector for predicted labels
test_y_hat = np.zeros(T)
# Calculating predicted labels
for i in range(T):
    test_y_hat[i] = B[0] + B[1]*test_x[i]

# Mean square error for the testing sample
error = np.square(test_y - test_y_hat).mean()
error_train = np.square(y - y_hat).mean()
print('MSE between the predicted and ground truth labels in testing data:',error_train)
print('MSE between the predicted and ground truth labels for testing data :', error)

# Displaying the data
plt.plot(x,y,'go',label='Training data')
plt.plot(test_x,test_y_hat,'rx',label='Testing data')
plt.plot(x,y_hat)
plt.axis('equal')
plt.grid(True)
plt.legend(loc='best')
plt.show()
print('Observations : The ML model performs poorly on the test and the training data. It is underfitting, does not fit the data well enough.')
